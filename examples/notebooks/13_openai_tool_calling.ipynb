# %% [markdown]
# # OpenAI tool-calling template

# %%
# !pip install tsontology

# %%
from tsontology import openai_function_schemas, ts_profile
print(openai_function_schemas(format='dict'))
print(ts_profile([0, 1, 0, 1], budget='lean'))
