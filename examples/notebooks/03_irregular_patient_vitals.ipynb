# %% [markdown]
# # Irregular patient vitals

# %% [markdown]
# A minimal clinical-monitoring notebook showing why timing irregularity is not just missing data.

# %%
from tsontology import starter_dataset, profile_dataset
case = starter_dataset("irregular_patient_vitals")
profile = profile_dataset(case["values"])
print(profile.to_summary_card_markdown(audience="clinical"))
