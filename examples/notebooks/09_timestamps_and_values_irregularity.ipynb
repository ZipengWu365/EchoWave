# %% [markdown]
# # Timestamps + values → irregularity report
#
# Show why explicit timestamps change the story.

# %%
from pathlib import Path
import numpy as np
from tsontology import profile_dataset

raw = np.genfromtxt(Path("../data/timestamps_values_irregular.csv"), delimiter=",", skip_header=1)
profile = profile_dataset(raw[:, 1], timestamps=raw[:, 0], domain="clinical")
print(profile.to_narrative_report())
