# %% [markdown]
# # tsontology Colab quickstart
# This notebook is designed as a low-friction hosted demo.

# %%
# !pip install tsontology

# %%
import numpy as np
from tsontology import profile_dataset
x = np.sin(np.linspace(0, 8*np.pi, 128))
print(profile_dataset(x).to_summary_card_markdown())
