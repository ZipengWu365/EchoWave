# %% [markdown]
# # Two curves → similarity verdict
#
# The smallest curve-comparison example.

# %%
import numpy as np
from tsontology import explain_similarity

t = np.linspace(0, 8*np.pi, 128)
left = np.sin(t)
right = np.sin(t + 0.15)
print(explain_similarity(left, right))
