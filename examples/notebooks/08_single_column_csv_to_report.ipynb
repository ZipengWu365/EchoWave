# %% [markdown]
# # Single-column CSV → report
#
# The smallest possible beginner example.

# %%
from pathlib import Path
import numpy as np
from tsontology import profile_dataset

path = Path("../data/single_column_signal.csv")
data = np.genfromtxt(path, delimiter=",", skip_header=1)
print(profile_dataset(data).to_summary_card_markdown())
