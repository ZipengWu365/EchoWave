# %% [markdown]
# # Single sensor drift -> structural watchouts
#
# A beginner engineering example: show why slow drift changes what normal means.

# %%
import pandas as pd
from tsontology import profile_dataset
df = pd.read_csv('../data/single_sensor_drift.csv')
report = profile_dataset(df['value'].to_numpy(), domain='engineering')
print(report.to_summary_card_markdown())
