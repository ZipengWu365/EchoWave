# %% [markdown]
# # pandas integration template

# %%
# !pip install tsontology pandas

# %%
import pandas as pd
from tsontology import starter_dataset, profile_dataset
case = starter_dataset('weekly_website_traffic')
df = pd.DataFrame(case['values'], columns=case['channels'])
print(profile_dataset(df, domain='traffic').to_summary_card_markdown())
